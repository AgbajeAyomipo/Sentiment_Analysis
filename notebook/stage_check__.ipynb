# %%
cd ..
# Out:
# c:\Users\Ayo Agbaje\Documents\Code\Python\GIGS\PYTHON_docs\py_files\Sentiment_Analysis

# %%
from stages.analyze_ import analyze
from stages.data_load import data_load
from stages.data_split import data_split
from stages.evaluate_ import evaluate
from stages.featurize import featurize
from stages.train_ import train

# %%
data_load()
# Out:
# Data Loaded Successfully

# %%
analyze()
# Out:
# All Data Analyzed and plots saved

# %%
featurize()
# Out:
# Features have been extracted and all new datasets saved to disk

# %%
data_split()
# Out:
# All Data Splitted and saved to disk

# %%
train()
# Out:
# Model Successfully Trained

# %%
evaluate()
# Out:
# All necessary evaluations done, Results and plots saved
